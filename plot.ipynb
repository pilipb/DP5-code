# %%
from power_calcs import power_calc
import numpy as np

# plot a range (output) of areas needed to achieve 400W for an input range of velocities
velocities = np.linspace(0.5,2.6,20)
areas = np.zeros(len(velocities))

for i,v in enumerate(velocities):
    p, e, r, areas[i], v = power_calc(P=400, efficiency=0.35, V=v)

# draw a vertical line at the point where y = 1
x = np.linspace(0,2.6,20)
y = np.ones(len(x))
plt.plot(x,y,'r--')

# draw a vertical line at the 20% velocity given the distribution is 0.14 to 0.26
y = np.linspace(0,10,20)
x = np.ones(len(x))
plt.plot(x,y,'g--')


import matplotlib.pyplot as plt
plt.plot(velocities, areas)
plt.xlabel('Velocity (m/s)')
plt.ylabel('Minimum Area (m^2)')
plt.show()
# Out:
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  9.142857142857142
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  9.142857142857142
#
# Velocity =  0.5
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  5.022023980365855
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  5.022023980365855
#
# Velocity =  0.6105263157894737
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  3.048534037472545
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  3.048534037472545
#
# Velocity =  0.7210526315789474
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  1.9873826266424008
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  1.9873826266424008
#
# Velocity =  0.8315789473684211
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  1.3667643957675635
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  1.3667643957675635
#
# Velocity =  0.9421052631578948
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.9798571428571424
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.9798571428571424
#
# Velocity =  1.0526315789473686
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.7262329154375011
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.7262329154375011
#
# Velocity =  1.1631578947368422
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.5531038123198371
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.5531038123198371
#
# Velocity =  1.2736842105263158
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.4309089399461814
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.4309089399461814
#
# Velocity =  1.3842105263157896
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.34221396620149375
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.34221396620149375
#
# Velocity =  1.4947368421052634
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.27628240752687283
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.27628240752687283
#
# Velocity =  1.605263157894737
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.22625591909597648
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.22625591909597648
#
# Velocity =  1.7157894736842105
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.187613603683515
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.187613603683515
#
# Velocity =  1.8263157894736843
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.15729296310864274
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.15729296310864274
#
# Velocity =  1.9368421052631581
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.13316924755416848
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.13316924755416848
#
# Velocity =  2.0473684210526315
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.11373684570533134
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.11373684570533134
#
# Velocity =  2.1578947368421053
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.0979086222604042
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.0979086222604042
#
# Velocity =  2.268421052631579
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.08488626898326271
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.08488626898326271
#
# Velocity =  2.378947368421053
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.07407460215555388
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.07407460215555388
#
# Velocity =  2.4894736842105267
#
# -------------------------------------------
#
# -------------------------------------------
#
#
# ---------Calculating Area---------
# Area =  0.06502373366278691
#
# -------------------------------------------
# All variables calculated.
#
# Power =  400
#
# efficiency =  0.35
#
# Area =  0.06502373366278691
#
# Velocity =  2.6
#
# -------------------------------------------
